# %%
# importing Pandas

import pandas as pd

# %%
#loading the data

df=pd.read_csv('TestMatch_Data - Test matches _ Batting records _ Highest career batting average _ ESPNcricinfo.csv')

# %%
df
# Out:
#                  Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0      DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1        AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2       RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3       GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4       GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                  ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60    GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 61    WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 62      SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 63  M Labuschagne (AUS)  2018-2025  55*    97   7  4338   215  48.20   8340
# 64     DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# ...

# %%
# Renaming the colums

df = df.rename(columns={'Mat':'Matches','NO':'Not_Out','HS':'Highest_Inns_Score','BF':'Ball_Faced','SR':'Batting_Strike_Rate','0':'Ducks'})

# %%
df
# Out:
#                  Player       Span Matches  Inns  Not_Out  Runs  \
# 0      DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1        AC Voges (AUS)  2015-2016      20    31        7  1485
# 2       RG Pollock (SA)  1963-1970      23    41        4  2256
# 3       GA Headley (WI)  1930-1954      22    40        4  2190
# 4       GA Headley (WI)  1930-1954      22    40        4  2190
# ..                  ...        ...     ...   ...      ...   ...
# 60    GC Smith (ICC/SA)  2002-2014     117   205       13  9265
# 61    WH Ponsford (AUS)  1924-1934      29    48        4  2122
# 62      SJ McCabe (AUS)  1930-1938      39    62        5  2748
# 63  M Labuschagne (AUS)  2018-2025     55*    97        7  4338
# 64     DR Jardine (ENG)  1928-1934      22    33        6  1296
#
#    Highest_Inns_Score    Ave Ball_Faced  Batting_Strike_Rate  100  50  Ducks  \
# 0                 334  99.94      9800+                58.60   29  13      7
# ...

# %%
# Checking duplicate values

df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# Not_Out                False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Ball_Faced             False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# Ducks                  False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df.dropna()
# Out:
#                  Player       Span Matches  Inns  Not_Out  Runs  \
# 0      DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1        AC Voges (AUS)  2015-2016      20    31        7  1485
# 2       RG Pollock (SA)  1963-1970      23    41        4  2256
# 3       GA Headley (WI)  1930-1954      22    40        4  2190
# 4       GA Headley (WI)  1930-1954      22    40        4  2190
# ..                  ...        ...     ...   ...      ...   ...
# 60    GC Smith (ICC/SA)  2002-2014     117   205       13  9265
# 61    WH Ponsford (AUS)  1924-1934      29    48        4  2122
# 62      SJ McCabe (AUS)  1930-1938      39    62        5  2748
# 63  M Labuschagne (AUS)  2018-2025     55*    97        7  4338
# 64     DR Jardine (ENG)  1928-1934      22    33        6  1296
#
#    Highest_Inns_Score    Ave Ball_Faced  Batting_Strike_Rate  100  50  Ducks  \
# 0                 334  99.94      9800+                58.60   29  13      7
# ...

# %%
# Check duplicate

df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 60     True
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#                Player       Span Matches  Inns  Not_Out   Runs  \
# 4     GA Headley (WI)  1930-1954      22    40        4   2190
# 28   BC Lara (ICC/WI)  1990-2006     131   232        6  11953
# 60  GC Smith (ICC/SA)  2002-2014     117   205       13   9265
#
#    Highest_Inns_Score    Ave Ball_Faced  Batting_Strike_Rate  100  50  Ducks  \
# 4                270*  60.83       416+                56.00   10   5      2
# 28               400*  52.88      19753                60.51   34  48     17
# 60                277  48.25      15525                59.67   27  38     11
#
#       4s  6s
# 4   104+   1
# 28  1559  88
# 60  1165  24

# %%
df = df.drop_duplicates()

# %%
df.duplicated() # Now the Duplicate values got removed
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 5     False
#       ...
# 59    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 62, dtype: bool

# %%
df[df['Player'].isin(['GA Headley (WI)','BC Lara (ICC/WI)','GC Smith (ICC/SA)'])]

#Now we can see those playes having only one data info
# Out:
#                Player       Span Matches  Inns  Not_Out   Runs  \
# 3     GA Headley (WI)  1930-1954      22    40        4   2190
# 27   BC Lara (ICC/WI)  1990-2006     131   232        6  11953
# 59  GC Smith (ICC/SA)  2002-2014     117   205       13   9265
#
#    Highest_Inns_Score    Ave Ball_Faced  Batting_Strike_Rate  100  50  Ducks  \
# 3                270*  60.83       416+                56.00   10   5      2
# 27               400*  52.88      19753                60.51   34  48     17
# 59                277  48.25      15525                59.67   27  38     11
#
#       4s  6s
# 3   104+   1
# 27  1559  88
# 59  1165  24

# %%
# Split up span into Start and End Date

df['Span'].dtype
# Out:
# dtype('O')

# %%
df['Span']
# Out:
# 0     1928-1948
# 1     2015-2016
# 2     1963-1970
# 3     1930-1954
# 5     1924-1935
#         ...
# 59    2002-2014
# 61    1924-1934
# 62    1930-1938
# 63    2018-2025
# 64    1928-1934
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-') # Now values got splitted
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 5     [1924, 1935]
#           ...
# 59    [2002, 2014]
# 61    [1924, 1934]
# 62    [1930, 1938]
# 63    [2018, 2025]
# 64    [1928, 1934]
# Name: Span, Length: 62, dtype: object

# %%
df['Span'].str.split(pat='-').str[0] #Split the 1st set value
# Out:
# 0     1928
# 1     2015
# 2     1963
# 3     1930
# 5     1924
#       ...
# 59    2002
# 61    1924
# 62    1930
# 63    2018
# 64    1928
# Name: Span, Length: 62, dtype: object

# %%
#Now assigning that 1st set value to debut_innings

df['Debut_Innings']=df['Span'].str.split(pat='-').str[0]
# Out:
# /var/folders/jh/bm563yw14hs1tm_f1784pny00000gn/T/ipykernel_43131/272754135.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Debut_Innings']=df['Span'].str.split(pat='-').str[0]

# %%
df #Debut_Innings column added
# Out:
#                  Player       Span Matches  Inns  Not_Out  Runs  \
# 0      DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1        AC Voges (AUS)  2015-2016      20    31        7  1485
# 2       RG Pollock (SA)  1963-1970      23    41        4  2256
# 3       GA Headley (WI)  1930-1954      22    40        4  2190
# 5     H Sutcliffe (ENG)  1924-1935      54    84        9  4555
# ..                  ...        ...     ...   ...      ...   ...
# 59    GC Smith (ICC/SA)  2002-2014     117   205       13  9265
# 61    WH Ponsford (AUS)  1924-1934      29    48        4  2122
# 62      SJ McCabe (AUS)  1930-1938      39    62        5  2748
# 63  M Labuschagne (AUS)  2018-2025     55*    97        7  4338
# 64     DR Jardine (ENG)  1928-1934      22    33        6  1296
#
#    Highest_Inns_Score    Ave Ball_Faced  Batting_Strike_Rate  100  50  Ducks  \
# 0                 334  99.94      9800+                58.60   29  13      7
# ...

# %%
# Now adding the 2nd set (Last_year)

df['Span'].str.split(pat='-').str[1]
# Out:
# 0     1948
# 1     2016
# 2     1970
# 3     1954
# 5     1935
#       ...
# 59    2014
# 61    1934
# 62    1938
# 63    2025
# 64    1934
# Name: Span, Length: 62, dtype: object

# %%
df['Last_year']= df['Span'].str.split(pat='-').str[1]
# Out:
# /var/folders/jh/bm563yw14hs1tm_f1784pny00000gn/T/ipykernel_43131/1873436782.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Last_year']= df['Span'].str.split(pat='-').str[1]

# %%
df
# Out:
#                  Player       Span Matches  Inns  Not_Out  Runs  \
# 0      DG Bradman (AUS)  1928-1948      52    80       10  6996
# 1        AC Voges (AUS)  2015-2016      20    31        7  1485
# 2       RG Pollock (SA)  1963-1970      23    41        4  2256
# 3       GA Headley (WI)  1930-1954      22    40        4  2190
# 5     H Sutcliffe (ENG)  1924-1935      54    84        9  4555
# ..                  ...        ...     ...   ...      ...   ...
# 59    GC Smith (ICC/SA)  2002-2014     117   205       13  9265
# 61    WH Ponsford (AUS)  1924-1934      29    48        4  2122
# 62      SJ McCabe (AUS)  1930-1938      39    62        5  2748
# 63  M Labuschagne (AUS)  2018-2025     55*    97        7  4338
# 64     DR Jardine (ENG)  1928-1934      22    33        6  1296
#
#    Highest_Inns_Score    Ave Ball_Faced  Batting_Strike_Rate  100  50  Ducks  \
# 0                 334  99.94      9800+                58.60   29  13      7
# ...

# %%
#Now droping the Span column

df.drop(['Span'],axis=1,inplace=True)
# Out:
# /var/folders/jh/bm563yw14hs1tm_f1784pny00000gn/T/ipykernel_43131/289546981.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Span'],axis=1,inplace=True)

# %%
df.head()
# Out:
#               Player Matches  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman (AUS)      52    80       10  6996                334  99.94
# 1     AC Voges (AUS)      20    31        7  1485               269*  61.87
# 2    RG Pollock (SA)      23    41        4  2256                274  60.97
# 3    GA Headley (WI)      22    40        4  2190               270*  60.83
# 5  H Sutcliffe (ENG)      54    84        9  4555                194  60.73
#
#   Ball_Faced  Batting_Strike_Rate  100  50  Ducks    4s  6s Debut_Innings  \
# 0      9800+                58.60   29  13      7  626+   6          1928
# 1       2667                55.68    5   4      2   186   5          2015
# 2      1707+                54.48    7  11      1  246+  11          1963
# 3       416+                56.00   10   5      2  104+   1          1930
# 5      6558+                34.59   16  23      2  202+   6          1924
#
#   Last_year
# 0      1948
# 1      2016
# 2      1970
# ...

# %%
# In the player name we are seeing the country name so removing it

df['Player'].str.split(pat='(').str[0]
# Out:
# 0        DG Bradman
# 1          AC Voges
# 2        RG Pollock
# 3        GA Headley
# 5       H Sutcliffe
#            ...
# 59         GC Smith
# 61      WH Ponsford
# 62        SJ McCabe
# 63    M Labuschagne
# 64       DR Jardine
# Name: Player, Length: 62, dtype: object

# %%
#Assigning this to the new column name (Player_Name)

df['Player_Name']=df['Player'].str.split(pat='(').str[0]
# Out:
# /var/folders/jh/bm563yw14hs1tm_f1784pny00000gn/T/ipykernel_43131/656972383.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Player_Name']=df['Player'].str.split(pat='(').str[0]

# %%
# Now need to create the country column (We can use the value which we splitted from the Player column)

df['Player'].str.split(pat='(').str[1]
# Out:
# 0        AUS)
# 1        AUS)
# 2         SA)
# 3         WI)
# 5        ENG)
#        ...
# 59    ICC/SA)
# 61       AUS)
# 62       AUS)
# 63       AUS)
# 64       ENG)
# Name: Player, Length: 62, dtype: object

# %%
df['Country']=df['Player'].str.split(pat='(').str[1]
# Out:
# /var/folders/jh/bm563yw14hs1tm_f1784pny00000gn/T/ipykernel_43131/2799593456.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country']=df['Player'].str.split(pat='(').str[1]

# %%
df['Country']=df['Country'].str.split(pat=')').str[0]
# Out:
# /var/folders/jh/bm563yw14hs1tm_f1784pny00000gn/T/ipykernel_43131/1791978499.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Country']=df['Country'].str.split(pat=')').str[0]

# %%
#Now droping the "Player" Columns (Name+country)

df.drop(['Player'],axis=1,inplace=True)
# Out:
# /var/folders/jh/bm563yw14hs1tm_f1784pny00000gn/T/ipykernel_43131/4001174169.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(['Player'],axis=1,inplace=True)

# %%
df
# Out:
#    Matches  Inns  Not_Out  Runs Highest_Inns_Score    Ave Ball_Faced  \
# 0       52    80       10  6996                334  99.94      9800+
# 1       20    31        7  1485               269*  61.87       2667
# 2       23    41        4  2256                274  60.97      1707+
# 3       22    40        4  2190               270*  60.83       416+
# 5       54    84        9  4555                194  60.73      6558+
# ..     ...   ...      ...   ...                ...    ...        ...
# 59     117   205       13  9265                277  48.25      15525
# 61      29    48        4  2122                266  48.22      3118+
# 62      39    62        5  2748                232  48.21      3217+
# 63     55*    97        7  4338                215  48.20       8340
# 64      22    33        6  1296                127  48.00      2110+
#
#     Batting_Strike_Rate  100  50  Ducks    4s  6s Debut_Innings Last_year  \
# ...

# %%
df.head()
# Out:
#   Matches  Inns  Not_Out  Runs Highest_Inns_Score    Ave Ball_Faced  \
# 0      52    80       10  6996                334  99.94      9800+
# 1      20    31        7  1485               269*  61.87       2667
# 2      23    41        4  2256                274  60.97      1707+
# 3      22    40        4  2190               270*  60.83       416+
# 5      54    84        9  4555                194  60.73      6558+
#
#    Batting_Strike_Rate  100  50  Ducks    4s  6s Debut_Innings Last_year  \
# 0                58.60   29  13      7  626+   6          1928      1948
# 1                55.68    5   4      2   186   5          2015      2016
# 2                54.48    7  11      1  246+  11          1963      1970
# 3                56.00   10   5      2  104+   1          1930      1954
# 5                34.59   16  23      2  202+   6          1924      1935
#
#     Player_Name Country
# 0   DG Bradman      AUS
# 1     AC Voges      AUS
# 2   RG Pollock       SA
# ...

# %%
df = df[[df.columns[-2]] + list(df.columns[:-2]) + [df.columns[-1]]] #Changed the column to 1st row

# %%
df.head()
# Out:
#     Player_Name Matches  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0   DG Bradman       52    80       10  6996                334  99.94
# 1     AC Voges       20    31        7  1485               269*  61.87
# 2   RG Pollock       23    41        4  2256                274  60.97
# 3   GA Headley       22    40        4  2190               270*  60.83
# 5  H Sutcliffe       54    84        9  4555                194  60.73
#
#   Ball_Faced  Batting_Strike_Rate  100  50  Ducks    4s  6s Debut_Innings  \
# 0      9800+                58.60   29  13      7  626+   6          1928
# 1       2667                55.68    5   4      2   186   5          2015
# 2      1707+                54.48    7  11      1  246+  11          1963
# 3       416+                56.00   10   5      2  104+   1          1930
# 5      6558+                34.59   16  23      2  202+   6          1924
#
#   Last_year Country
# 0      1948     AUS
# 1      2016     AUS
# 2      1970      SA
# ...

# %%
df.dtypes
# Out:
# Player_Name             object
# Matches                 object
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Ball_Faced              object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# Ducks                    int64
# 4s                      object
# 6s                      object
# Debut_Innings           object
# Last_year               object
# Country                 object
# dtype: object

# %%
# Removing '*' from the Highest_Inns_Score

df['Highest_Inns_Score']=df['Highest_Inns_Score'].str.split(pat='*').str[0]

# %%
df
# Out:
#        Player_Name Matches  Inns  Not_Out  Runs Highest_Inns_Score    Ave  \
# 0      DG Bradman       52    80       10  6996                334  99.94
# 1        AC Voges       20    31        7  1485                269  61.87
# 2      RG Pollock       23    41        4  2256                274  60.97
# 3      GA Headley       22    40        4  2190                270  60.83
# 5     H Sutcliffe       54    84        9  4555                194  60.73
# ..             ...     ...   ...      ...   ...                ...    ...
# 59       GC Smith      117   205       13  9265                277  48.25
# 61    WH Ponsford       29    48        4  2122                266  48.22
# 62      SJ McCabe       39    62        5  2748                232  48.21
# 63  M Labuschagne      55*    97        7  4338                215  48.20
# 64     DR Jardine       22    33        6  1296                127  48.00
#
#    Ball_Faced  Batting_Strike_Rate  100  50  Ducks    4s  6s Debut_Innings  \
# ...

# %%
df['Highest_Inns_Score'].dtypes # Currently its in Objest
# Out:
# dtype('O')

# %%
# Now changing the data type

df['Highest_Inns_Score'] = df['Highest_Inns_Score'].astype(int)

# %%
df['Highest_Inns_Score'].dtypes
# Out:
# dtype('int64')

# %%
df.rename(columns={'Debut_Innings': 'Debut_Year'}, inplace=True)
df.head()
# Out:
#     Player_Name Matches  Inns  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 0   DG Bradman       52    80       10  6996                 334  99.94
# 1     AC Voges       20    31        7  1485                 269  61.87
# 2   RG Pollock       23    41        4  2256                 274  60.97
# 3   GA Headley       22    40        4  2190                 270  60.83
# 5  H Sutcliffe       54    84        9  4555                 194  60.73
#
#   Ball_Faced  Batting_Strike_Rate  100  50  Ducks    4s  6s Debut_Year  \
# 0      9800+                58.60   29  13      7  626+   6       1928
# 1       2667                55.68    5   4      2   186   5       2015
# 2      1707+                54.48    7  11      1  246+  11       1963
# 3       416+                56.00   10   5      2  104+   1       1930
# 5      6558+                34.59   16  23      2  202+   6       1924
#
#   Last_year Country
# 0      1948     AUS
# 1      2016     AUS
# 2      1970      SA
# ...

# %%
# Now changing the data types for the (Debut_Innings, Last_year)

df=df.astype({'Debut_Year':'int','Last_year':'int'})

# %%
df.dtypes
# Out:
# Player_Name             object
# Matches                 object
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Ball_Faced              object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# Ducks                    int64
# 4s                      object
# 6s                      object
# Debut_Year               int64
# Last_year                int64
# Country                 object
# dtype: object

# %%
# Formating Matches (Removing *)

df['Matches']=df['Matches'].str.split(pat='*').str[0]

# %%
# Now converting the 'Matches' dataType from Object to Int

df['Matches']=df['Matches'].astype(int)

# %%
df.dtypes
# Out:
# Player_Name             object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Ball_Faced              object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# Ducks                    int64
# 4s                      object
# 6s                      object
# Debut_Year               int64
# Last_year                int64
# Country                 object
# dtype: object

# %%
#Now formating the 4s and 6s

df['4s']=df['4s'].str.split('+').str[0]

# %%
df['6s']=df['6s'].str.split('+').str[0]

# %%
# Changing the dtypes of 4s and 6s from Object to Int

df=df.astype({'4s':'int','6s':'int'})

# %%
df.dtypes
# Out:
# Player_Name             object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Ball_Faced              object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# Ducks                    int64
# 4s                       int64
# 6s                       int64
# Debut_Year               int64
# Last_year                int64
# Country                 object
# dtype: object

# %%
# Formating Ballfaced

df['Ball_Faced']=df['Ball_Faced'].str.split(pat='+').str[0]

# %%
df['Ball_Faced']=df['Ball_Faced'].str.split(pat='-').str[0]

# %%
df['Ball_Faced'].unique()
# Out:
# array(['9800', '2667', '1707', '416', '6558', '1288', '4957', '', '2581',
#        '7491', '4063', '22882', '5363', '2844', '18605', '3030', '28903',
#        '178', '17913', '665', '1823', '13079', '108', '2703', '29437',
#        '19753', '15164', '31258', '14372', '19375', '22782', '2035',
#        '10636', '12436', '27395', '14184', '22461', '22568', '14349',
#        '16077', '27002', '9613', '2731', '22959', '16345', '488', '619',
#        '10441', '2445', '15456', '885', '158', '11641', '1799', '8662',
#        '15525', '3118', '3217', '8340', '2110'], dtype=object)

# %%
df[df['Ball_Faced'].isin([''])]
# Out:
#         Player_Name  Matches  Inns  Not_Out  Runs  Highest_Inns_Score    Ave  \
# 8        ED Weekes        48    81        5  4455                 207  58.61
# 14      CL Walcott        44    74        7  3798                 220  56.68
# 55  Hon.FS Jackson        20    33        4  1415                 144  48.79
#
#    Ball_Faced  Batting_Strike_Rate  100  50  Ducks   4s  6s  Debut_Year  \
# 8                              0.0   15  19      6  258   2        1948
# 14                             0.0   15  14      1  107  11        1948
# 55                             0.0    5   6      3   51   0        1893
#
#     Last_year Country
# 8        1958      WI
# 14       1960      WI
# 55       1905     ENG

# %%
# No info in ball faced , hence dropping the rows

df=df.drop(8,axis=0)

# %%
df=df.drop(55,axis=0)

# %%
df['Ball_Faced'].unique()
# Out:
# array(['9800', '2667', '1707', '416', '6558', '1288', '4957', '2581',
#        '7491', '4063', '22882', '5363', '2844', '18605', '3030', '28903',
#        '178', '17913', '665', '1823', '13079', '108', '2703', '29437',
#        '19753', '15164', '31258', '14372', '19375', '22782', '2035',
#        '10636', '12436', '27395', '14184', '22461', '22568', '14349',
#        '16077', '27002', '9613', '2731', '22959', '16345', '488', '619',
#        '10441', '2445', '15456', '885', '158', '11641', '1799', '8662',
#        '15525', '3118', '3217', '8340', '2110'], dtype=object)

# %%
df['Ball_Faced']=df['Ball_Faced'].astype(int)

# %%
df.dtypes
# Out:
# Player_Name             object
# Matches                  int64
# Inns                     int64
# Not_Out                  int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Ball_Faced               int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# Ducks                    int64
# 4s                       int64
# 6s                       int64
# Debut_Year               int64
# Last_year                int64
# Country                 object
# dtype: object

# %%
#Question-1: Find an total career length

df['Career_Length']=df['Last_year']-df['Debut_Year']

# %%
df
# Out:
#           Player_Name  Matches  Inns  Not_Out   Runs  Highest_Inns_Score  \
# 0         DG Bradman        52    80       10   6996                 334
# 1           AC Voges        20    31        7   1485                 269
# 2         RG Pollock        23    41        4   2256                 274
# 3         GA Headley        22    40        4   2190                 270
# 5        H Sutcliffe        54    84        9   4555                 194
# 6          E Paynter        20    31        5   1540                 243
# 7      KF Barrington        82   131       15   6806                 256
# 9           HC Brook        24    40        1   2281                 317
# 10        WR Hammond        85   140       16   7249                 336
# 11         GS Sobers        93   160       21   8032                 365
# 12     KC Sangakkara       134   233       17  12400                 319
# 13          JB Hobbs        61   102        7   5410                 211
# ...

# %%
# Question-2: Average career length

df['Career_Length'].mean()
# Out:
# 13.11864406779661

# %%
# Question-3: Average batting strike rate for cricketers who played more than 10years

df[df['Career_Length']>10]['Batting_Strike_Rate'].mean()
# Out:
# 50.13317073170732

# %%
# Question-4: Player who played before 1960

df[df['Debut_Year']<1960]['Player_Name'].count()
# Out:
# 20

# %%
# Question-5: Max highest Inns scored by country

df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        248
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int64

# %%
# Question-6: Highest number of 100's scored by country

df.groupby('Country')['100'].max()
# Out:
# Country
# AUS        41
# ENG        36
# ICC/IND    36
# ICC/PAK    25
# ICC/SA     45
# ICC/WI     34
# IND        51
# NZ         33
# PAK        34
# SA         22
# SL         38
# WI         30
# ZIM        12
# Name: 100, dtype: int64

# %%
# Average of 100,50,0's by countries

df.groupby('Country')[['100','50','Ducks']].mean()
# Out:
#                100         50      Ducks
# Country
# AUS      20.750000  28.562500   8.625000
# ENG      13.750000  22.666667   4.583333
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      23.250000  31.500000   8.000000
# NZ       33.000000  37.000000  11.000000
# PAK      17.800000  24.000000   7.800000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       17.166667  28.666667   8.500000
# ZIM      12.000000  27.000000   5.000000

# %%
import seaborn as sns
sns.set_theme(style='darkgrid')

# %%
sns.scatterplot(df.groupby('Country')[['100','50','Ducks']].mean())
# Out:
# <Axes: xlabel='Country'>
